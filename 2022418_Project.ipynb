# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import statsmodels.formula.api as smf
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # 1. Uploading datasets
# The most relevant, open-source and reliable dataset source is Earnings Analysis using Administrative Data Sources (EAADS), which links earnings from administrative sources to Labour Force Survey National Minimum Wage Estimates data. The data are administered by the Central Statistics Office (CSO) in Ireland.
#
# ### 1.1. Education level
# The dataset of Education level is the total number of Employees aged 15 years and over from the second quarter of 2016 to the third quarter of 2020. This dataset involves all level of the education level of the Total employees, Employees reporting earning National Minimum Wage or less and Employees reporting earning more than National Minimum Wage. Also, the type of the education level is “Primary or below”, “Lower secondary”, “post-secondary non-tertiary”, “Third level non-honours degree”, “Third level honours degree or higher” and “Higher secondary”.

# %%
# Dataset by education level
df_education= pd.read_csv("MWA27.20230614T090606.csv")
df_education
# Out:
#                       Statistic Label          Education Level  \
# 0    Employees aged 15 years and over  All levels of education
# 1    Employees aged 15 years and over  All levels of education
# 2    Employees aged 15 years and over  All levels of education
# 3    Employees aged 15 years and over  All levels of education
# 4    Employees aged 15 years and over  All levels of education
# ..                                ...                      ...
# 571  Employees aged 15 years and over         Other/not stated
# 572  Employees aged 15 years and over         Other/not stated
# 573  Employees aged 15 years and over         Other/not stated
# 574  Employees aged 15 years and over         Other/not stated
# 575  Employees aged 15 years and over         Other/not stated
#
#                                    NMW earnings status Quarter      UNIT  \
# 0    Employees reporting earning National Minimum W...  2016Q2  Thousand
# 1    Employees reporting earning National Minimum W...  2016Q3  Thousand
# 2    Employees reporting earning National Minimum W...  2016Q4  Thousand
# 3    Employees reporting earning National Minimum W...  2017Q1  Thousand
# 4    Employees reporting earning National Minimum W...  2017Q2  Thousand
# ..                                                 ...     ...       ...
# 571                                    Total employees  2019Q3  Thousand
# 572                                    Total employees  2019Q4  Thousand
# 573                                    Total employees  2020Q1  Thousand
# 574                                    Total employees  2020Q2  Thousand
# 575                                    Total employees  2020Q3  Thousand
#
#      VALUE
# 0    196.4
# 1    183.1
# 2    154.3
# 3    140.3
# 4    131.7
# ..     ...
# 571   58.3
# 572   56.5
# 573   57.0
# 574   38.5
# 575   45.8
#
# [576 rows x 6 columns]

# %%
df_education.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 576 entries, 0 to 575
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Statistic Label      576 non-null    object
#  1   Education Level      576 non-null    object
#  2   NMW earnings status  576 non-null    object
#  3   Quarter              576 non-null    object
#  4   UNIT                 576 non-null    object
#  5   VALUE                564 non-null    float64
# dtypes: float64(1), object(5)
# memory usage: 27.1+ KB

# %% [markdown]
# The "VALUE" of this dataset is the number of total employees.

# %%
df_education.describe()
# Out:
#              VALUE
# count   564.000000
# mean    243.398050
# std     439.083136
# min       3.900000
# 25%      19.150000
# 50%      52.650000
# 75%     219.025000
# max    2018.100000

# %% [markdown]
# ### 1.2. Nationality
#
# The Nationalities of the total number which are Employees aged 15 years and over from the second quarter of 2016 to the fourth quarter of 2019. The dataset involves the Nationalities of the Total employees, Employees reporting earning National Minimum Wage or less and Employees reporting earning more than National Minimum Wage. Moreover, the dataset is six different categories of the Nationalities which are “Irish nationals”, “non-Irish nationals”, “United Kingdom”, “EU 15 excl. Irl. & UK”, “EU15 to EU28” and “Other nationals”.

# %%
# Dataset by nationality
df_nat=pd.read_csv("MWA25.20230614T090635.csv")
df_nat
# Out:
#                       Statistic Label      Nationality  \
# 0    Employees aged 15 years and over    Total Persons
# 1    Employees aged 15 years and over    Total Persons
# 2    Employees aged 15 years and over    Total Persons
# 3    Employees aged 15 years and over    Total Persons
# 4    Employees aged 15 years and over    Total Persons
# ..                                ...              ...
# 415  Employees aged 15 years and over  Other nationals
# 416  Employees aged 15 years and over  Other nationals
# 417  Employees aged 15 years and over  Other nationals
# 418  Employees aged 15 years and over  Other nationals
# 419  Employees aged 15 years and over  Other nationals
#
#                                    NMW earnings status Quarter      UNIT  \
# 0    Employees reporting earning National Minimum W...  2016Q2  Thousand
# 1    Employees reporting earning National Minimum W...  2016Q3  Thousand
# 2    Employees reporting earning National Minimum W...  2016Q4  Thousand
# 3    Employees reporting earning National Minimum W...  2017Q1  Thousand
# 4    Employees reporting earning National Minimum W...  2017Q2  Thousand
# ..                                                 ...     ...       ...
# 415                                    Total employees  2018Q4  Thousand
# 416                                    Total employees  2019Q1  Thousand
# 417                                    Total employees  2019Q2  Thousand
# 418                                    Total employees  2019Q3  Thousand
# 419                                    Total employees  2019Q4  Thousand
#
#      VALUE
# 0    196.4
# 1    183.1
# 2    154.3
# 3    140.3
# 4    131.7
# ..     ...
# 415  118.0
# 416  121.2
# 417  129.7
# 418  132.8
# 419  128.3
#
# [420 rows x 6 columns]

# %%
df_nat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 420 entries, 0 to 419
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Statistic Label      420 non-null    object
#  1   Nationality          420 non-null    object
#  2   NMW earnings status  420 non-null    object
#  3   Quarter              420 non-null    object
#  4   UNIT                 420 non-null    object
#  5   VALUE                362 non-null    float64
# dtypes: float64(1), object(5)
# memory usage: 19.8+ KB

# %%
df_nat.describe()
# Out:
#              VALUE
# count   362.000000
# mean    340.763536
# std     575.056338
# min       4.200000
# 25%      35.700000
# 50%      99.150000
# 75%     193.075000
# max    2018.100000

# %% [markdown]
# ### 1.3. A Weekly Usual worked hours
# The proposed dependent variable of worked hours datasets was generated by weekly usual worked hours of employees who has aged 15 years and over from the second quarter of 2016 to the third quarter of 2020 with the national minimum wage earnings status. Also, the dataset provides information of employees who is earning more than National Minimum Wage.

# %%
# Dataset by worked hours
df_hours=pd.read_excel("MWA15.20230614T0906044.xlsx")
df_hours
# Out:
#                       Statistic Label  \
# 0    Employees aged 15 years and over
# 1    Employees aged 15 years and over
# 2    Employees aged 15 years and over
# 3    Employees aged 15 years and over
# 4    Employees aged 15 years and over
# ..                                ...
# 283  Employees aged 15 years and over
# 284  Employees aged 15 years and over
# 285  Employees aged 15 years and over
# 286  Employees aged 15 years and over
# 287  Employees aged 15 years and over
#
#                                    NMW earnings status  \
# 0    Employees reporting earning National Minimum W...
# 1    Employees reporting earning National Minimum W...
# 2    Employees reporting earning National Minimum W...
# 3    Employees reporting earning National Minimum W...
# 4    Employees reporting earning National Minimum W...
# ..                                                 ...
# 283  Employees reporting earning more than National...
# 284  Employees reporting earning more than National...
# 285  Employees reporting earning more than National...
# 286  Employees reporting earning more than National...
# 287  Employees reporting earning more than National...
#
#             Usual Hours Worked Quarter      UNIT  VALUE
# 0                    1-9 hours  2016Q2  Thousand   16.6
# 1                    1-9 hours  2016Q3  Thousand   12.2
# 2                    1-9 hours  2016Q4  Thousand   15.3
# 3                    1-9 hours  2017Q1  Thousand   13.7
# 4                    1-9 hours  2017Q2  Thousand   13.3
# ..                         ...     ...       ...    ...
# 283  Variable hours (see note)  2019Q3  Thousand   46.8
# 284  Variable hours (see note)  2019Q4  Thousand   47.3
# 285  Variable hours (see note)  2020Q1  Thousand   41.3
# 286  Variable hours (see note)  2020Q2  Thousand   30.8
# 287  Variable hours (see note)  2020Q3  Thousand   34.7
#
# [288 rows x 6 columns]

# %%
df_hours.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 288 entries, 0 to 287
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Statistic Label      288 non-null    object
#  1   NMW earnings status  288 non-null    object
#  2   Usual Hours Worked   288 non-null    object
#  3   Quarter              288 non-null    object
#  4   UNIT                 288 non-null    object
#  5   VALUE                284 non-null    float64
# dtypes: float64(1), object(5)
# memory usage: 13.6+ KB

# %%
df_hours.describe()
# Out:
#             VALUE
# count  284.000000
# mean   112.002465
# std    162.866112
# min      4.200000
# 25%     17.000000
# 50%     31.700000
# 75%    125.350000
# max    641.600000

# %% [markdown]
# ### 1.4. NACE Economic Sector
# NACE (Nomenclature of Economic Activities) is the European statistical classification of economic activities. NACE groups organizations according to their business activities. The dataset of those economic sectors was combined the total number of Employees aged 15 years and over from the second quarter of 2016 to the third quarter of 2020 with the national minimum wage earnings status.

# %%
# Dataset by economic sector
df_sector=pd.read_csv("MWA07.csv")
df_sector
# Out:
#                        Statistic Label NACE Rev 2 Economic Sector  \
# 0     Employees aged 15 years and over  All NACE economic sectors
# 1     Employees aged 15 years and over  All NACE economic sectors
# 2     Employees aged 15 years and over  All NACE economic sectors
# 3     Employees aged 15 years and over  All NACE economic sectors
# 4     Employees aged 15 years and over  All NACE economic sectors
# ...                                ...                        ...
# 1291  Employees aged 15 years and over                 Not stated
# 1292  Employees aged 15 years and over                 Not stated
# 1293  Employees aged 15 years and over                 Not stated
# 1294  Employees aged 15 years and over                 Not stated
# 1295  Employees aged 15 years and over                 Not stated
#
#                                     NMW earnings status Quarter      UNIT  \
# 0     Employees reporting earning National Minimum W...  2016Q2  Thousand
# 1     Employees reporting earning National Minimum W...  2016Q3  Thousand
# 2     Employees reporting earning National Minimum W...  2016Q4  Thousand
# 3     Employees reporting earning National Minimum W...  2017Q1  Thousand
# 4     Employees reporting earning National Minimum W...  2017Q2  Thousand
# ...                                                 ...     ...       ...
# 1291                                    Total employees  2019Q3  Thousand
# 1292                                    Total employees  2019Q4  Thousand
# 1293                                    Total employees  2020Q1  Thousand
# 1294                                    Total employees  2020Q2  Thousand
# 1295                                    Total employees  2020Q3  Thousand
#
#       VALUE
# 0     196.4
# 1     183.1
# 2     154.3
# 3     140.3
# 4     131.7
# ...     ...
# 1291    5.3
# 1292    5.9
# 1293    NaN
# 1294    NaN
# 1295    NaN
#
# [1296 rows x 6 columns]

# %%
df_sector.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1296 entries, 0 to 1295
# Data columns (total 6 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Statistic Label             1296 non-null   object
#  1   NACE Rev 2 Economic Sector  1296 non-null   object
#  2   NMW earnings status         1296 non-null   object
#  3   Quarter                     1296 non-null   object
#  4   UNIT                        1296 non-null   object
#  5   VALUE                       1094 non-null   float64
# dtypes: float64(1), object(5)
# memory usage: 60.9+ KB

# %%
df_sector.describe()
# Out:
#              VALUE
# count  1094.000000
# mean    186.669835
# std     385.207348
# min       3.000000
# 25%      14.325000
# 50%      84.500000
# 75%     147.275000
# max    2018.100000

# %% [markdown]
# # 2. Data preparation and Visualisation

# %% [markdown]
# ## **2.1. Usual Worked Hours**
# The data preparation process began with converting the date to a datetime format which was originally in an object type. This converting process was necessary because all dataset’s “Quarter” variables contain the unique time values. The correct datetime formats allows to process feature engineering, handling missing data and visualization.

# %%
# Convert to datetime objects
year_quarter_dates = [pd.Period(quarter, freq='Q') for quarter in df_hours['Quarter']]
dates = [qd.to_timestamp() for qd in year_quarter_dates]

df_hours["Quarter(hours)"]=dates
# Print the converted dates
print(df_hours["Quarter(hours)"].head())
# Out:
# 0   2016-04-01
# 1   2016-07-01
# 2   2016-10-01
# 3   2017-01-01
# 4   2017-04-01
# Name: Quarter(hours), dtype: datetime64[ns]

# %%
df_hours['Year(hours)'] = df_hours['Quarter(hours)'].dt.year
df_hours['Month(hours)'] = df_hours['Quarter(hours)'].dt.month
df_hours.head()
# Out:
#                     Statistic Label  \
# 0  Employees aged 15 years and over
# 1  Employees aged 15 years and over
# 2  Employees aged 15 years and over
# 3  Employees aged 15 years and over
# 4  Employees aged 15 years and over
#
#                                  NMW earnings status Usual Hours Worked  \
# 0  Employees reporting earning National Minimum W...          1-9 hours
# 1  Employees reporting earning National Minimum W...          1-9 hours
# 2  Employees reporting earning National Minimum W...          1-9 hours
# 3  Employees reporting earning National Minimum W...          1-9 hours
# 4  Employees reporting earning National Minimum W...          1-9 hours
#
#   Quarter      UNIT  VALUE Quarter(hours)  Year(hours)  Month(hours)
# 0  2016Q2  Thousand   16.6     2016-04-01         2016             4
# 1  2016Q3  Thousand   12.2     2016-07-01         2016             7
# 2  2016Q4  Thousand   15.3     2016-10-01         2016            10
# 3  2017Q1  Thousand   13.7     2017-01-01         2017             1
# 4  2017Q2  Thousand   13.3     2017-04-01         2017             4

# %%
# Check for missing values in the DataFrame
missing_values = df_hours.isnull().sum()
# Display the count of missing values for each column
print(missing_values)
# Out:
# Statistic Label        0
# NMW earnings status    0
# Usual Hours Worked     0
# Quarter                0
# UNIT                   0
# VALUE                  4
# Quarter(hours)         0
# Year(hours)            0
# Month(hours)           0
# dtype: int64

# %%
# Drop rows with missing values
df_hours = df_hours.dropna()
df_hours.shape
# Out:
# (284, 9)

# %% [markdown]
# Next step is dropping irrelevant rows from each columns of the datasets. Because as mentioned earlier, the datasets contained a significant amount of irrelevant information. For instance, the counts of workers earning more than National Minimum Wage workers, “Not stated” entries, “Total employees”, All NACE economic sectors, among others.

# %%
# Drop rows where "NMW earnings status" is "Total employees", "Employees reporting earning more than National Minimum Wage", "Variable hours (see note)"  or "Not Stated"
df_h = df_hours.drop(df_hours[(df_hours["NMW earnings status"] == "Total employees")
                           | (df_hours["Usual Hours Worked"] == "Variable hours (see note)") 
                           | (df_hours["NMW earnings status"] == "Total employees") 
                           | (df_hours["NMW earnings status"] == "Not stated")].index)
df_h.shape
# Out:
# (248, 9)

# %%
# Define a custom color palette
custom_palette = ['#d62728', '#2ca02c']
sns.set(style='whitegrid', palette=custom_palette)

# Create a grid layout with 3 rows and 2 columns
fig, axes = plt.subplots(3, 2, figsize=(12, 12))

# Create subplots for each year
years = df_h['Year(hours)'].unique()
num_years = len(years)

# Iterate over years and axes
for i, year in enumerate(years):
    # Filter data for the current year
    data_year = df_h[df_h['Year(hours)'] == year]
    
    # Determine the subplot position based on row and column
    row = i // 2
    col = i % 2
    
    # Calculate the total VALUE for the current year
    total_value = data_year['VALUE'].sum()
    
    # Normalize the data by dividing VALUE by the total VALUE for the current year
    data_year['VALUE'] = (data_year['VALUE'] / total_value) * 100
    
    # Create a side-by-side bar chart for the current year in the appropriate subplot
    ax = axes[row, col]
    sns.barplot(data=data_year, x='Usual Hours Worked', y='VALUE', hue='NMW earnings status', ax=ax)
    ax.set_title(f'Year {year}')
    ax.set_xlabel('Usual Hours Worked')
    ax.set_ylabel('Percentage')
    
    # Rotate x-axis labels by 45 degrees
    ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
    
    # Annotate each bar with percentage values
    for p in ax.patches:
        height = p.get_height()
        ax.annotate(f'{height:.1f}%', (p.get_x() + p.get_width() / 2., height),
                    ha='center', va='center', fontsize=10, color='black', xytext=(0, 5),
                    textcoords='offset points')
    
# Hide the empty subplot (row 1, column 2)
fig.delaxes(axes[2, 1])
fig.suptitle('NMW Earnings Status by Weekly usual Hours Worked by Year (Percentage)', fontsize=16, fontweight='bold')
plt.tight_layout(rect=[0, 0, 1, 0.94])
plt.show()

# %% [markdown]
# Based on the statistical information, it was observed that from 2016 to 2020 the majority of minimum wage workers worked between 10-29 hours per week. Furthermore, the study found that the of number of minimum wage workers working these usual weekly hours decreased towards the end of 2020.

# %%
# Drop rows where "NMW earnings status" is "Total employees", "Employees reporting earning more than National Minimum Wage", "Variable hours (see note)"  or "Not Stated"
df_h = df_h.drop(df_h[(df_h["NMW earnings status"] == "Employees reporting earning more than National Minimum Wage")].index) 
df_h.shape
# Out:
# (122, 9)

# %%
# to change the name of the 'VALUE' column
df_h.rename(columns={'VALUE': 'VALUE(hours)'}, inplace=True)
df_h.head()
# Out:
#                     Statistic Label  \
# 0  Employees aged 15 years and over
# 1  Employees aged 15 years and over
# 2  Employees aged 15 years and over
# 3  Employees aged 15 years and over
# 4  Employees aged 15 years and over
#
#                                  NMW earnings status Usual Hours Worked  \
# 0  Employees reporting earning National Minimum W...          1-9 hours
# 1  Employees reporting earning National Minimum W...          1-9 hours
# 2  Employees reporting earning National Minimum W...          1-9 hours
# 3  Employees reporting earning National Minimum W...          1-9 hours
# 4  Employees reporting earning National Minimum W...          1-9 hours
#
#   Quarter      UNIT  VALUE(hours) Quarter(hours)  Year(hours)  Month(hours)
# 0  2016Q2  Thousand          16.6     2016-04-01         2016             4
# 1  2016Q3  Thousand          12.2     2016-07-01         2016             7
# 2  2016Q4  Thousand          15.3     2016-10-01         2016            10
# 3  2017Q1  Thousand          13.7     2017-01-01         2017             1
# 4  2017Q2  Thousand          13.3     2017-04-01         2017             4

# %% [markdown]
# ### **2.2. Nationality**

# %%
# Convert to datetime objects
year_quarter_dates = [pd.Period(quarter, freq='Q') for quarter in df_nat['Quarter']]
dates = [qd.to_timestamp() for qd in year_quarter_dates]

df_nat["Quarter(hours)"]=dates
# Print the converted dates
print(df_nat["Quarter(hours)"])
# Out:
# 0     2016-04-01
# 1     2016-07-01
# 2     2016-10-01
# 3     2017-01-01
# 4     2017-04-01
#          ...
# 415   2018-10-01
# 416   2019-01-01
# 417   2019-04-01
# 418   2019-07-01
# 419   2019-10-01
# Name: Quarter(hours), Length: 420, dtype: datetime64[ns]

# %%
df_nat['Year(nationality)'] = df_nat['Quarter(hours)'].dt.year
df_nat['Month(nationality)'] = df_nat['Quarter(hours)'].dt.month
df_nat.head()
# Out:
#                     Statistic Label    Nationality  \
# 0  Employees aged 15 years and over  Total Persons
# 1  Employees aged 15 years and over  Total Persons
# 2  Employees aged 15 years and over  Total Persons
# 3  Employees aged 15 years and over  Total Persons
# 4  Employees aged 15 years and over  Total Persons
#
#                                  NMW earnings status Quarter      UNIT  VALUE  \
# 0  Employees reporting earning National Minimum W...  2016Q2  Thousand  196.4
# 1  Employees reporting earning National Minimum W...  2016Q3  Thousand  183.1
# 2  Employees reporting earning National Minimum W...  2016Q4  Thousand  154.3
# 3  Employees reporting earning National Minimum W...  2017Q1  Thousand  140.3
# 4  Employees reporting earning National Minimum W...  2017Q2  Thousand  131.7
#
#   Quarter(hours)  Year(nationality)  Month(nationality)
# 0     2016-04-01               2016                   4
# 1     2016-07-01               2016                   7
# 2     2016-10-01               2016                  10
# 3     2017-01-01               2017                   1
# 4     2017-04-01               2017                   4

# %%
# Drop rows where "NMW earnings status" is "Total employees", "Employees reporting earning more than National Minimum Wage"
df_nat = df_nat.drop(df_nat[(df_nat["NMW earnings status"] == "Total employees") 
                           | (df_nat["Nationality"] == "Total Persons")    
                           | (df_nat["NMW earnings status"] == "Employees reporting earning more than National Minimum Wage")].index)

# %%
# to change the name of the 'VALUE' column
df_nat.rename(columns={'VALUE': 'VALUE(nationality)'}, inplace=True)

# %%
# Check for missing values in the DataFrame
missing_values_nation = df_nat.isnull().sum()
# Display the count of missing values for each column
print(missing_values_nation)
# Out:
# Statistic Label         0
# Nationality             0
# NMW earnings status     0
# Quarter                 0
# UNIT                    0
# VALUE(nationality)     58
# Quarter(hours)          0
# Year(nationality)       0
# Month(nationality)      0
# dtype: int64

# %%
# Drop rows with missing values
df_nation = df_nat.dropna()
# Check for missing values in the DataFrame
missing_values_nat = df_nation.isnull().sum()
# Check the DataFrame after dropping the rows with missing values
print(missing_values_nat)
# Out:
# Statistic Label        0
# Nationality            0
# NMW earnings status    0
# Quarter                0
# UNIT                   0
# VALUE(nationality)     0
# Quarter(hours)         0
# Year(nationality)      0
# Month(nationality)     0
# dtype: int64

# %%
# Define a cool color palette
cool_colors = sns.color_palette("cool", n_colors=8)

# Group the filtered data by year and nationality, and sum the 'VALUE' column
grouped_data = df_nation.groupby(['Year(nationality)', 'Nationality'])['VALUE(nationality)'].sum().reset_index()

# Set style for the plot
sns.set(style='ticks', palette='colorblind')

# Create a grid layout with two rows and two columns
fig, axes = plt.subplots(2, 2, figsize=(12, 10), sharey=True)

# Create subplots for years
years = grouped_data['Year(nationality)'].unique()[:4]  
num_years = len(years)

# Iterate over years and axes
for i, year in enumerate(years):
    # Filter data for the current year
    data_year = grouped_data[grouped_data['Year(nationality)'] == year]
    
    # Determine the subplot position based on row and column
    row = i // 2
    col = i % 2
    
    # Calculate the total value for the current year
    total_value = data_year['VALUE(nationality)'].sum()
    
    # Create a column (bar) chart for the current year in the appropriate subplot
    ax = axes[row, col]
    bars = ax.bar(data_year['Nationality'], data_year['VALUE(nationality)'] / total_value * 100, color=cool_colors[:len(data_year)])
    ax.set_title(f'Year {year}')
    ax.tick_params(axis='x', rotation=45)
    
    # Add percentage labels above each bar
    for bar in bars:
        height = bar.get_height()
        ax.annotate(f'{height:.1f}%', xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3), textcoords='offset points',
                    ha='center', va='bottom')

    # Set labels for the first subplot in each row
    if col == 0:
        ax.set_ylabel('Percentage')

# Add a common title for the subplots
fig.suptitle('NMW Employee Distribution by Nationality', fontsize=16, fontweight='bold')
plt.tight_layout(rect=[0, 0.05, 1, 0.94])
plt.show()

# %% [markdown]
# Subplots shows the number of NMW employees by nationality. The results were different than the proposed hypotheses, which was mentioned that most of the minimum wage workers would be non-Irish. Furthermore, the highlight finding of the result was that the number of Irish NMW workers increased by 64.9% to 72.8% each year, while the number of non-Irish nationals decreased by 2.4%.

# %%
replacement_dict_sector = {
    'Irish nationals': 0,
    'Non-Irish nationals': 1,
    'United Kingdom': 2,
    'EU 15 excl. Irl. & UK': 3,
    'EU15 to EU28': 4,
    'Other nationals': 5
}

df_nation['Nationality'] = df_nation['Nationality'].replace(replacement_dict_sector)
df_nation.head()
# Out:
#                      Statistic Label  Nationality  \
# 60  Employees aged 15 years and over            0
# 61  Employees aged 15 years and over            0
# 62  Employees aged 15 years and over            0
# 63  Employees aged 15 years and over            0
# 64  Employees aged 15 years and over            0
#
#                                   NMW earnings status Quarter      UNIT  \
# 60  Employees reporting earning National Minimum W...  2016Q2  Thousand
# 61  Employees reporting earning National Minimum W...  2016Q3  Thousand
# 62  Employees reporting earning National Minimum W...  2016Q4  Thousand
# 63  Employees reporting earning National Minimum W...  2017Q1  Thousand
# 64  Employees reporting earning National Minimum W...  2017Q2  Thousand
#
#     VALUE(nationality) Quarter(hours)  Year(nationality)  Month(nationality)
# 60               147.3     2016-04-01               2016                   4
# 61               141.6     2016-07-01               2016                   7
# 62               116.7     2016-10-01               2016                  10
# 63               103.3     2017-01-01               2017                   1
# 64               100.4     2017-04-01               2017                   4

# %% [markdown]
# ### **2.3. Economic sector**

# %%
df_sector
# Out:
#                        Statistic Label NACE Rev 2 Economic Sector  \
# 0     Employees aged 15 years and over  All NACE economic sectors
# 1     Employees aged 15 years and over  All NACE economic sectors
# 2     Employees aged 15 years and over  All NACE economic sectors
# 3     Employees aged 15 years and over  All NACE economic sectors
# 4     Employees aged 15 years and over  All NACE economic sectors
# ...                                ...                        ...
# 1291  Employees aged 15 years and over                 Not stated
# 1292  Employees aged 15 years and over                 Not stated
# 1293  Employees aged 15 years and over                 Not stated
# 1294  Employees aged 15 years and over                 Not stated
# 1295  Employees aged 15 years and over                 Not stated
#
#                                     NMW earnings status Quarter      UNIT  \
# 0     Employees reporting earning National Minimum W...  2016Q2  Thousand
# 1     Employees reporting earning National Minimum W...  2016Q3  Thousand
# 2     Employees reporting earning National Minimum W...  2016Q4  Thousand
# 3     Employees reporting earning National Minimum W...  2017Q1  Thousand
# 4     Employees reporting earning National Minimum W...  2017Q2  Thousand
# ...                                                 ...     ...       ...
# 1291                                    Total employees  2019Q3  Thousand
# 1292                                    Total employees  2019Q4  Thousand
# 1293                                    Total employees  2020Q1  Thousand
# 1294                                    Total employees  2020Q2  Thousand
# 1295                                    Total employees  2020Q3  Thousand
#
#       VALUE
# 0     196.4
# 1     183.1
# 2     154.3
# 3     140.3
# 4     131.7
# ...     ...
# 1291    5.3
# 1292    5.9
# 1293    NaN
# 1294    NaN
# 1295    NaN
#
# [1296 rows x 6 columns]

# %%
# drop all "Not stated" values and "All NACE economic secpors" from "NACE Rev 2 Economic Sector"
df_sect=df_sector.drop(df_sector[(df_sector["NACE Rev 2 Economic Sector"] == "Not stated")
                               |(df_sector["NACE Rev 2 Economic Sector"] == "All NACE economic sectors")].index)

# Drop rows where "NMW earnings status" is "Total employees", "Employees reporting earning more than National Minimum Wage" or "Not Stated"
df_sec = df_sect.drop(df_sect[(df_sect["NMW earnings status"] == "Total employees") 
                           | (df_sect["NMW earnings status"] == "Employees reporting earning more than National Minimum Wage") 
                           | (df_sect["VALUE"] == "NaN")
                           | (df_sect["NMW earnings status"] == "Not stated")].index)
df_sec.shape
# Out:
# (288, 6)

# %%
# Check for missing values in the DataFrame
missing_values = df_sec.isnull().sum()
# Display the count of missing values for each column
print(missing_values)
# Out:
# Statistic Label                 0
# NACE Rev 2 Economic Sector      0
# NMW earnings status             0
# Quarter                         0
# UNIT                            0
# VALUE                         105
# dtype: int64

# %%
# Drop rows with missing values
df_se = df_sec.dropna()
m_values = df_se.isnull().sum()
# Check the DataFrame after dropping the rows with missing values
print(m_values)
# Out:
# Statistic Label               0
# NACE Rev 2 Economic Sector    0
# NMW earnings status           0
# Quarter                       0
# UNIT                          0
# VALUE                         0
# dtype: int64

# %%
# Convert to datetime objects
year_quarter_dates = [pd.Period(quarter, freq='Q') for quarter in df_se['Quarter']]
dates = [qd.to_timestamp() for qd in year_quarter_dates]

df_se["Quarter(hours)"]=dates

# %%
df_se['Year(sector)'] = df_se['Quarter(hours)'].dt.year
df_se['Month(sector)'] = df_se['Quarter(hours)'].dt.month
df_se.head()
# Out:
#                      Statistic Label             NACE Rev 2 Economic Sector  \
# 72  Employees aged 15 years and over  Agriculture, forestry and fishing (A)
# 73  Employees aged 15 years and over  Agriculture, forestry and fishing (A)
# 74  Employees aged 15 years and over  Agriculture, forestry and fishing (A)
# 75  Employees aged 15 years and over  Agriculture, forestry and fishing (A)
# 77  Employees aged 15 years and over  Agriculture, forestry and fishing (A)
#
#                                   NMW earnings status Quarter      UNIT  \
# 72  Employees reporting earning National Minimum W...  2016Q2  Thousand
# 73  Employees reporting earning National Minimum W...  2016Q3  Thousand
# 74  Employees reporting earning National Minimum W...  2016Q4  Thousand
# 75  Employees reporting earning National Minimum W...  2017Q1  Thousand
# 77  Employees reporting earning National Minimum W...  2017Q3  Thousand
#
#     VALUE Quarter(hours)  Year(sector)  Month(sector)
# 72    8.1     2016-04-01          2016              4
# 73    6.4     2016-07-01          2016              7
# 74    3.9     2016-10-01          2016             10
# 75    5.5     2017-01-01          2017              1
# 77    5.0     2017-07-01          2017              7

# %%
# Filter the data to get the sum of 'VALUE' for each sector
sector_totals = df_se.groupby('NACE Rev 2 Economic Sector')['VALUE'].sum().reset_index()

# Create the pie chart
plt.figure(figsize=(8, 8))
plt.pie(sector_totals['VALUE'], labels=sector_totals['NACE Rev 2 Economic Sector'], autopct='%1.1f%%', startangle=140)

# Add a title
plt.title('Employees by NACE Rev 2 Economic Sector', fontsize=16, fontweight='bold')

# Display the pie chart
plt.show()

# %% [markdown]
# Feature Engineering is the process of transforming raw data into useful features that help us to understand our model better and increase its predictive power.

# %%
replacement_dict_sector = {
    'Agriculture, forestry and fishing (A)': 0,
    'Construction (F)': 1,
    'Wholesale and retail trade, repair of motor vehicles and motorcycles (G)': 2,
    'Transportation and storage (H)': 3,
    'Accommodation and food service activities (I)': 4,
    'Information and communication (J)':5,
    'Professional, scientific and technical activities (M)': 6,
    'Administrative and support service activities (N)': 7,
    'Public administration and defence, compulsory social security (O)':8,
    'Education (P)': 9,
    'Human health and social work activities (Q)': 10,
    'Industry (B to E)': 11,
    'Industry and Construction (B to F)': 12,
    'Services (G to U)': 13,
    'Financial, insurance and real estate activities (K,L)':14,
    'Other NACE activities (R to U)': 15
}

df_se['NACE Rev 2 Economic Sector'] = df_se['NACE Rev 2 Economic Sector'].replace(replacement_dict_sector)

# %%
# Assuming you have a DataFrame named 'df' and you want to get the unique values in a column named 'column_name'
unique_values = df_se['NACE Rev 2 Economic Sector'].unique()

# Print the unique values
print(unique_values)
# Out:
# [ 0  1  2  3  4  6  7  9 10 11 12 13 15]

# %%
# to change the name of the 'VALUE' column
df_se.rename(columns={'VALUE': 'VALUE(sector)'}, inplace=True)

# %%
# Assuming your DataFrame is named 'df'
df_se = df_se[df_se['VALUE(sector)'] >= 8.0]
df_se
# Out:
#                        Statistic Label  NACE Rev 2 Economic Sector  \
# 72    Employees aged 15 years and over                           0
# 144   Employees aged 15 years and over                           1
# 216   Employees aged 15 years and over                           2
# 217   Employees aged 15 years and over                           2
# 218   Employees aged 15 years and over                           2
# ...                                ...                         ...
# 1165  Employees aged 15 years and over                          15
# 1166  Employees aged 15 years and over                          15
# 1167  Employees aged 15 years and over                          15
# 1168  Employees aged 15 years and over                          15
# 1169  Employees aged 15 years and over                          15
#
#                                     NMW earnings status Quarter      UNIT  \
# 72    Employees reporting earning National Minimum W...  2016Q2  Thousand
# 144   Employees reporting earning National Minimum W...  2016Q2  Thousand
# 216   Employees reporting earning National Minimum W...  2016Q2  Thousand
# 217   Employees reporting earning National Minimum W...  2016Q3  Thousand
# 218   Employees reporting earning National Minimum W...  2016Q4  Thousand
# ...                                                 ...     ...       ...
# 1165  Employees reporting earning National Minimum W...  2019Q3  Thousand
# 1166  Employees reporting earning National Minimum W...  2019Q4  Thousand
# 1167  Employees reporting earning National Minimum W...  2020Q1  Thousand
# 1168  Employees reporting earning National Minimum W...  2020Q2  Thousand
# 1169  Employees reporting earning National Minimum W...  2020Q3  Thousand
#
#       VALUE(sector) Quarter(hours)  Year(sector)  Month(sector)
# 72              8.1     2016-04-01          2016              4
# 144             8.1     2016-04-01          2016              4
# 216            52.6     2016-04-01          2016              4
# 217            47.0     2016-07-01          2016              7
# 218            42.7     2016-10-01          2016             10
# ...             ...            ...           ...            ...
# 1165           11.4     2019-07-01          2019              7
# 1166           10.6     2019-10-01          2019             10
# 1167            8.9     2020-01-01          2020              1
# 1168           11.0     2020-04-01          2020              4
# 1169           12.7     2020-07-01          2020              7
#
# [129 rows x 9 columns]

# %% [markdown]
# ### **2.4. Education level**

# %%
df_education
# Out:
#                       Statistic Label          Education Level  \
# 0    Employees aged 15 years and over  All levels of education
# 1    Employees aged 15 years and over  All levels of education
# 2    Employees aged 15 years and over  All levels of education
# 3    Employees aged 15 years and over  All levels of education
# 4    Employees aged 15 years and over  All levels of education
# ..                                ...                      ...
# 571  Employees aged 15 years and over         Other/not stated
# 572  Employees aged 15 years and over         Other/not stated
# 573  Employees aged 15 years and over         Other/not stated
# 574  Employees aged 15 years and over         Other/not stated
# 575  Employees aged 15 years and over         Other/not stated
#
#                                    NMW earnings status Quarter      UNIT  \
# 0    Employees reporting earning National Minimum W...  2016Q2  Thousand
# 1    Employees reporting earning National Minimum W...  2016Q3  Thousand
# 2    Employees reporting earning National Minimum W...  2016Q4  Thousand
# 3    Employees reporting earning National Minimum W...  2017Q1  Thousand
# 4    Employees reporting earning National Minimum W...  2017Q2  Thousand
# ..                                                 ...     ...       ...
# 571                                    Total employees  2019Q3  Thousand
# 572                                    Total employees  2019Q4  Thousand
# 573                                    Total employees  2020Q1  Thousand
# 574                                    Total employees  2020Q2  Thousand
# 575                                    Total employees  2020Q3  Thousand
#
#      VALUE
# 0    196.4
# 1    183.1
# 2    154.3
# 3    140.3
# 4    131.7
# ..     ...
# 571   58.3
# 572   56.5
# 573   57.0
# 574   38.5
# 575   45.8
#
# [576 rows x 6 columns]

# %%
# Drop rows where "NMW earnings status" is "Total employees", "Employees reporting earning more than National Minimum Wage" or "Not Stated"
df_edu = df_education.drop(df_education[(df_education["Education Level"] == "All levels of education") 
                           | (df_education["Education Level"] == "Other/not stated") 
                           | (df_education["NMW earnings status"] == "Employees reporting earning more than National Minimum Wage") 
                           | (df_education["NMW earnings status"] == "Total employees") 
                           | (df_education["NMW earnings status"] == "Not stated")].index)
df_edu.shape
# Out:
# (108, 6)

# %%
# Convert to datetime objects
year_quarter_dates = [pd.Period(quarter, freq='Q') for quarter in df_edu['Quarter']]
dates = [qd.to_timestamp() for qd in year_quarter_dates]
df_edu["Quarter(hours)"]=dates

# %%
# Check for missing values in the DataFrame
missing_values = df_edu.isnull().sum()
# Display the count of missing values for each column
print(missing_values)
# Out:
# Statistic Label        0
# Education Level        0
# NMW earnings status    0
# Quarter                0
# UNIT                   0
# VALUE                  0
# Quarter(hours)         0
# dtype: int64

# %%
# to change the name of the 'VALUE' column
df_edu.rename(columns={'VALUE': 'VALUE(education)'}, inplace=True)

# %%
df_edu['Year(education)'] = df_edu['Quarter(hours)'].dt.year
df_edu['Month(education)'] = df_edu['Quarter(hours)'].dt.month
df_edu.head()
# Out:
#                      Statistic Label   Education Level  \
# 72  Employees aged 15 years and over  Primary or below
# 73  Employees aged 15 years and over  Primary or below
# 74  Employees aged 15 years and over  Primary or below
# 75  Employees aged 15 years and over  Primary or below
# 76  Employees aged 15 years and over  Primary or below
#
#                                   NMW earnings status Quarter      UNIT  \
# 72  Employees reporting earning National Minimum W...  2016Q2  Thousand
# 73  Employees reporting earning National Minimum W...  2016Q3  Thousand
# 74  Employees reporting earning National Minimum W...  2016Q4  Thousand
# 75  Employees reporting earning National Minimum W...  2017Q1  Thousand
# 76  Employees reporting earning National Minimum W...  2017Q2  Thousand
#
#     VALUE(education) Quarter(hours)  Year(education)  Month(education)
# 72               8.1     2016-04-01             2016                 4
# 73               6.5     2016-07-01             2016                 7
# 74               7.2     2016-10-01             2016                10
# 75               5.8     2017-01-01             2017                 1
# 76               4.8     2017-04-01             2017                 4

# %%
# Calculate the total VALUE(education) for each year
total_per_year = df_edu.groupby('Year(education)')['VALUE(education)'].transform('sum')
df_edu['Percentage(education)'] = (df_edu['VALUE(education)'] / total_per_year) * 100

# Set the style for the plot
sns.set(style='whitegrid', palette='colorblind')

# Create the figure and axis objects
fig, ax1 = plt.subplots(figsize=(12, 6))

# Plot component bar chart with 'Year' on the x-axis, 'Percentage(education)' on the y-axis, and 'Education Level' as the hue
sns.barplot(data=df_edu, x='Year(education)', y='Percentage(education)', hue='Education Level', ax=ax1, palette='viridis')

# Set the label for the y-axis
ax1.set_ylabel('Percentage(education)', fontsize=14, fontweight='bold')

# Add labels to the graph
plt.xlabel('Year(education)', fontsize=14, fontweight='bold')
plt.title('Component Bar Chart of Percentage of Employees by Education Level', fontsize=16, fontweight='bold')

# Display the percentage values on the bars
for p in ax1.patches:
    ax1.annotate(f'{p.get_height():.2f}%', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', fontsize=12, color='black', xytext=(0, 10),
                textcoords='offset points')

# Rotate x-axis labels for better visibility
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
replacement_dict_edu = {
    'Primary or below': 0,
    'Lower secondary': 1,
    'Post-secondary non-tertiary': 2,
    'Third level non-honours degree': 3,
    'Third level honours degree or higher':4,
    'Higher secondary': 5,
}

df_edu['Education Level'] = df_edu['Education Level'].replace(replacement_dict_edu)

# %%
df_edu.dtypes
# Out:
# Statistic Label                  object
# Education Level                   int64
# NMW earnings status              object
# Quarter                          object
# UNIT                             object
# VALUE(education)                float64
# Quarter(hours)           datetime64[ns]
# Year(education)                   int64
# Month(education)                  int64
# Percentage(education)           float64
# dtype: object

# %% [markdown]
# # 3. Applying Machine Learning Models

# %% [markdown]
# X was created by selected valuable variables from four different datasets for use in machine learning methods

# %%
# Collecting X and Y values
vars_df1 = df_h[['VALUE(hours)', 'Year(hours)', "Month(hours)"]] 
vars_df2 = df_nation[['VALUE(nationality)', 'Nationality', 'Year(nationality)', "Month(nationality)"]] 
vars_df3 = df_se[['VALUE(sector)', 'NACE Rev 2 Economic Sector', 'Year(sector)', "Month(sector)"]] 
vars_df4 = df_edu[['VALUE(education)', 'Education Level', 'Year(education)', "Month(education)"]]  
 

# Concatenate the selected variables horizontally to create x_train
X= pd.concat([vars_df1, vars_df2, vars_df3, vars_df4], axis=1)
y=df_h["Usual Hours Worked"].values

# %%
# Reset the indices of selected variable DataFrames
vars_df1_reset = vars_df1.reset_index(drop=True)
vars_df2_reset = vars_df2.reset_index(drop=True)
vars_df3_reset = vars_df3.reset_index(drop=True)
vars_df4_reset = vars_df4.reset_index(drop=True)

# Concatenate the selected variables horizontally to create x
X = pd.concat([vars_df1_reset, vars_df2_reset, vars_df3_reset, vars_df4_reset], axis=1)

# %%
X.to_csv('out.csv', index=False)

# %%
print("X shape:", X.shape)
print("y shape:", y.shape)
# Out:
# X shape: (129, 15)
# y shape: (122,)

# %% [markdown]
# ### Splitting the dataset into the Training set and Test set

# %%
# Check for missing values in X 
mis_values = X.isnull().sum()
# Display the count of missing values for each column
print(mis_values)
# Out:
# VALUE(hours)                   7
# Year(hours)                    7
# Month(hours)                   7
# VALUE(nationality)             7
# Nationality                    7
# Year(nationality)              7
# Month(nationality)             7
# VALUE(sector)                  0
# NACE Rev 2 Economic Sector     0
# Year(sector)                   0
# Month(sector)                  0
# VALUE(education)              21
# Education Level               21
# Year(education)               21
# Month(education)              21
# dtype: int64

# %%
# Drop the last 14 rows from the DataFrame 'df'
X = X.iloc[:-21]
y = y[:-14]

# %%
miss_values = X.isnull().sum()
print(miss_values)
# Out:
# VALUE(hours)                  0
# Year(hours)                   0
# Month(hours)                  0
# VALUE(nationality)            0
# Nationality                   0
# Year(nationality)             0
# Month(nationality)            0
# VALUE(sector)                 0
# NACE Rev 2 Economic Sector    0
# Year(sector)                  0
# Month(sector)                 0
# VALUE(education)              0
# Education Level               0
# Year(education)               0
# Month(education)              0
# dtype: int64

# %% [markdown]
# #### Cross-Validation

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC

# Create instances of the models to compare
models = {
    "Logistic Regression": LogisticRegression(),
    "Random Forest": RandomForestClassifier(n_estimators=100),
    "Decision Tree": DecisionTreeClassifier(),
    "Naive Bayes": GaussianNB(),
    "SVM": SVC(),
}

# Perform cross-validation and compare models
num_folds = 5  # Number of cross-validation folds

mean_scores = {}

for model_name, model in models.items():
    scores = cross_val_score(model, X, y, cv=num_folds, scoring='accuracy')
    mean_score = np.mean(scores)
    mean_scores[model_name] = mean_score

# Print the mean accuracy scores for each model
for model_name, mean_score in mean_scores.items():
    print(f"Mean Accuracy for {model_name}: {mean_score}")

# Choose the model with the highest mean accuracy score
chosen_model_name = max(mean_scores, key=mean_scores.get)
chosen_model = models[chosen_model_name]

print(f"Selected Model: {chosen_model_name}")

# Train the chosen model on the full dataset
chosen_model.fit(X, y)
# Out:
# Mean Accuracy for Logistic Regression: 0.9073593073593074
# Mean Accuracy for Random Forest: 0.9454545454545455
# Mean Accuracy for Decision Tree: 0.8891774891774892
# Mean Accuracy for Naive Bayes: 0.9454545454545455
# Mean Accuracy for SVM: 0.32597402597402597
# Selected Model: Random Forest
# RandomForestClassifier()

# %% [markdown]
# Based on the mean accuracy scores from cross-validation, the Random Forest classifier has the highest accuracy, making it the selected model for my dataset. The selected model achieved a mean accuracy of approximately 94.55%.

# %% [markdown]
# ## 4.1. Random Forest

# %%
# Load the library 'sklearn.model_selection'
from sklearn.model_selection import train_test_split

# Split the data set into Training and Testing parts
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 20)

# Display the Number of rows and columns before (X, y) and after Splitting (X_train, X_test, y_train, y_test)
X.shape, y.shape, X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((108, 15), (108,), (81, 15), (27, 15), (81,), (27,))

# %%
#Import Random Forest Model
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
#Create three RandomForestClassifier models
clf = RandomForestClassifier(n_estimators = 100)
model2=RandomForestClassifier(n_estimators = 150)
model3=RandomForestClassifier(n_estimators = 50)
#Train the model using the training sets 
clf.fit(X_train,y_train)
model2.fit(X_train,y_train)
model3.fit(X_train,y_train)
# Make predictions with the individual models
y1_pred = clf.predict(X_test)
pred2 = model2.predict(X_test)
pred3 = model3.predict(X_test)
# Calculate accuracy for each model and the ensemble
accuracy1 = accuracy_score(y_test, y1_pred)
accuracy2 = accuracy_score(y_test, pred2)
accuracy3 = accuracy_score(y_test, pred3)
# Display the accuracy for each model and the ensemble
print("Accuracy for Model 1:", accuracy1)
print("Accuracy for Model 2:", accuracy2)
print("Accuracy for Model 3:", accuracy3)
# Out:
# Accuracy for Model 1: 0.8888888888888888
# Accuracy for Model 2: 0.9259259259259259
# Accuracy for Model 3: 0.8888888888888888

# %%
#Import scikit-learn metrics module for accuracy calculation
from sklearn import metrics    
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y1_pred))
# Out:
# Accuracy: 0.8888888888888888

# %% [markdown]
# A confusion matrix is a tool for summarizing the performance of a classification algorithm. A confusion matrix will give us a clear picture of classification model performance and the types of errors produced by the model. It gives us a summary of correct and incorrect predictions broken down by each category. The summary is represented in a tabular form.

# %%
from sklearn.metrics import classification_report, confusion_matrix

# Calculate cm by calling a method named as 'confusion_matrix'
cm2 = confusion_matrix(y_test, y1_pred)

# Call a method heatmap() to plot confusion matrix
sns.heatmap(cm2, annot = True)

# print the classification_report based on y_test and y_predict
print(classification_report(y_test, y1_pred))
# Out:
#               precision    recall  f1-score   support
#
#    1-9 hours       1.00      1.00      1.00         5
#  10-19 hours       0.60      1.00      0.75         3
#  20-29 hours       0.83      0.71      0.77         7
#  30-34 hours       1.00      0.75      0.86         4
#  35-39 hours       1.00      1.00      1.00         5
#  40-44 hours       1.00      1.00      1.00         3
#
#     accuracy                           0.89        27
#    macro avg       0.91      0.91      0.90        27
# weighted avg       0.91      0.89      0.89        27

# %% [markdown]
# The overall accuracy of the model is 0.89, which means it correctly classifies 89% of the instances in the dataset. The macro average and weighted average F1-scores are both 0.89, indicating good overall model performance.

# %%
# Use of Cross-Validation
from sklearn.model_selection import cross_val_score
cross_val_score(clf, X, y, scoring='accuracy').mean()
# Out:
# 0.9264069264069266

# %%
pd.crosstab(y_test, y1_pred, rownames=["Actual hours"], colnames=["Predicted hours"])
# Out:
# Predicted hours  1-9 hours  10-19 hours  20-29 hours  30-34 hours  \
# Actual hours
# 1-9 hours                5            0            0            0
# 10-19 hours              0            3            0            0
# 20-29 hours              0            2            5            0
# 30-34 hours              0            0            1            3
# 35-39 hours              0            0            0            0
# 40-44 hours              0            0            0            0
#
# Predicted hours  35-39 hours  40-44 hours
# Actual hours
# 1-9 hours                  0            0
# 10-19 hours                0            0
# 20-29 hours                0            0
# 30-34 hours                0            0
# 35-39 hours                5            0
# 40-44 hours                0            3

# %% [markdown]
# ### Finding Important Features in Scikit-learn

# %%
feature_imp = pd.Series(clf.feature_importances_, index=['VALUE(hours)', 'Year(hours)', "Month(hours)",
                       'VALUE(nationality)', 'Nationality', 'Year(nationality)', "Month(nationality)",                                 
                       'VALUE(sector)', 'NACE Rev 2 Economic Sector', 'Year(sector)', "Month(sector)",
                       'VALUE(education)', 'Education Level', 'Year(education)', "Month(education)"                                
                        ]).sort_values(ascending=False)
feature_imp
# Out:
# VALUE(education)              0.186919
# Education Level               0.180598
# NACE Rev 2 Economic Sector    0.157721
# VALUE(nationality)            0.131445
# VALUE(hours)                  0.119087
# VALUE(sector)                 0.096945
# Nationality                   0.073016
# Year(nationality)             0.010022
# Year(sector)                  0.009233
# Year(education)               0.008135
# Year(hours)                   0.006887
# Month(nationality)            0.006608
# Month(sector)                 0.005649
# Month(education)              0.004228
# Month(hours)                  0.003508
# dtype: float64

# %%
# Creating a bar plot
sns.barplot(x=feature_imp, y=feature_imp.index)
# Add labels to your graph
plt.xlabel('Feature Importance Score')
plt.ylabel('Features')
plt.title("Visualization Important Features")
#plt.legend()
plt.show()

# %% [markdown]
# ## 3.2. Decision Trees

# %%
# K-Fold Cross-Validation
from sklearn.model_selection import StratifiedKFold
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import f1_score

# Number of folds
k = 5
# Initialize the StratifiedKFold object
skf = StratifiedKFold(n_splits=k)
# Initialize a classifier (e.g., Decision Tree)
clf = DecisionTreeClassifier()
# Lists to store F1 scores for each fold
f1_scores = []
# Perform stratified k-fold cross-validation
for train_index, test_index in skf.split(X, y):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y[train_index], y[test_index]
    
    # Fit the model on the training data
    clf.fit(X_train, y_train)
    
    # Make predictions on the test data
    y_pred = clf.predict(X_test)
    
    # Calculate F1 score and store it
    f1 = f1_score(y_test, y_pred, average='macro')  # Use 'macro' for multiclass
    f1_scores.append(f1)
    
# Calculate the average F1 score
average_f1 = sum(f1_scores) / k
print("Average F1 Score:", average_f1)
# Out:
# Average F1 Score: 0.9222222222222222

# %% [markdown]
# Calculated the average F1 score for my multiclass classification problem. An F1 score of 0.968 is quite high, indicating that my model is performing well in terms of precision and recall for the classes in the dataset.

# %%
X.to_csv('output_file.csv', index=False)

# %%
# CHANGING MAX_DEPTH
score_train=[]
score_test=[]

for i in range(1,10):
    dtree_model = DecisionTreeClassifier(max_depth=i)
    dtree_model.fit(X_train,y_train)
    
    score_train.append(dtree_model.score(X_train,y_train)*100)
    score_test.append(dtree_model.score(X_test,y_test)*100)
    print(f"max_depth = {i}: Training Accuracy = {score_train[i-1]:.2f}%, Testing Accuracy = {score_test[i-1]:.2f}%")    

score_train_array=np.asarray(score_train)
score_test_array=np.asarray(score_test)
plt.figure(figsize=(10,6))
plt.plot(range(1,10),score_train_array,color='blue', label="Training_accuracy")
plt.plot(range(1,10),score_test_array,color='red',label="Testing_accuracy")

plt.legend()
plt.xlabel('max_depth')
plt.ylabel('Accuracy%')
plt.show()
# Out:
# max_depth = 1: Training Accuracy = 34.48%, Testing Accuracy = 28.57%
# max_depth = 2: Training Accuracy = 51.72%, Testing Accuracy = 42.86%
# max_depth = 3: Training Accuracy = 67.82%, Testing Accuracy = 61.90%
# max_depth = 4: Training Accuracy = 100.00%, Testing Accuracy = 100.00%
# max_depth = 5: Training Accuracy = 100.00%, Testing Accuracy = 80.95%
# max_depth = 6: Training Accuracy = 100.00%, Testing Accuracy = 80.95%
# max_depth = 7: Training Accuracy = 100.00%, Testing Accuracy = 80.95%
# max_depth = 8: Training Accuracy = 100.00%, Testing Accuracy = 100.00%
# max_depth = 9: Training Accuracy = 100.00%, Testing Accuracy = 100.00%

# %% [markdown]
# 	These results highlight the importance of finding the right balance for ‘max_depth’ to prevent overfitting and choose the best generalization. A ‘max_depth’ of 4 was reasonable choice in this dataset, as it provided the highest testing accuracy without overfitting.

# %%
# Create and initialise Decision Tree with max_depth = 4

classifier = DecisionTreeClassifier(max_depth = 4)

# Train the classifier by calling a method 'fit()'
classifier.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=4)

# %%
# Calculate the predicted vlaue by calling a method predict()
y1_pred = classifier.predict(X_test)
y1_pred[0:10]
# Out:
# array(['1-9 hours', '1-9 hours', '1-9 hours', '10-19 hours',
#        '10-19 hours', '10-19 hours', '10-19 hours', '20-29 hours',
#        '20-29 hours', '20-29 hours'], dtype=object)

# %%
# Check for overfitting and underfitting¶
print('Test set score: {:.4f}'.format(classifier.score(X_test, y_test)))
# Out:
# Test set score: 1.0000

# %% [markdown]
# Here, the test-set accuracy to be 0.80.

# %% [markdown]
# ### Making the Confusion Matrix

# %%
# Calculate cm by calling a method named as 'confusion_matrix'
cm = confusion_matrix(y_test, y_pred)

# Call a method heatmap() to plot confusion matrix
sns.heatmap(cm, annot = True)

# print the classification_report based on y_test and y_predict
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#    1-9 hours       1.00      1.00      1.00         3
#  10-19 hours       0.00      0.00      0.00         4
#  20-29 hours       0.43      1.00      0.60         3
#  30-34 hours       1.00      1.00      1.00         4
#  35-39 hours       1.00      1.00      1.00         4
#  40-44 hours       1.00      1.00      1.00         3
#
#     accuracy                           0.81        21
#    macro avg       0.74      0.83      0.77        21
# weighted avg       0.73      0.81      0.75        21

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy is:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy is: 0.8095238095238095

# %%
from sklearn import tree

# Set the size of the figure
plt.figure(figsize = (12, 8))

# Display the tree by calling a method plot_tree()
tree.plot_tree(classifier.fit(X_train, y_train))
# Out:
# [Text(0.5, 0.9, 'x[11] <= 45.95\ngini = 0.833\nsamples = 87\nvalue = [15, 14, 15, 14, 14, 15]'),
#  Text(0.375, 0.7, 'x[12] <= 0.5\ngini = 0.8\nsamples = 72\nvalue = [15, 14, 15, 14, 14, 0]'),
#  Text(0.25, 0.5, 'gini = 0.0\nsamples = 15\nvalue = [15, 0, 0, 0, 0, 0]'),
#  Text(0.5, 0.5, 'x[12] <= 2.5\ngini = 0.75\nsamples = 57\nvalue = [0, 14, 15, 14, 14, 0]'),
#  Text(0.25, 0.3, 'x[3] <= 41.15\ngini = 0.499\nsamples = 29\nvalue = [0, 14, 15, 0, 0, 0]'),
#  Text(0.125, 0.1, 'gini = 0.0\nsamples = 15\nvalue = [0, 0, 15, 0, 0, 0]'),
#  Text(0.375, 0.1, 'gini = 0.0\nsamples = 14\nvalue = [0, 14, 0, 0, 0, 0]'),
#  Text(0.75, 0.3, 'x[0] <= 16.05\ngini = 0.5\nsamples = 28\nvalue = [0, 0, 0, 14, 14, 0]'),
#  Text(0.625, 0.1, 'gini = 0.0\nsamples = 14\nvalue = [0, 0, 0, 14, 0, 0]'),
#  Text(0.875, 0.1, 'gini = 0.0\nsamples = 14\nvalue = [0, 0, 0, 0, 14, 0]'),
#  Text(0.625, 0.7, 'gini = 0.0\nsamples = 15\nvalue = [0, 0, 0, 0, 0, 15]')]

# %% [markdown]
# ### Implementation
# So, I have created a model that uses decision tree algorithm to predict the weekly usual working hours of minimum wage workers. The Accuracy of the model is 81.4%.

# %% [markdown]
# ### 4.3. Naive Bayes Classification

# %%
# Fitting Naive Bayes Classification to the Training set
from sklearn.naive_bayes import GaussianNB

# Create and initialise an object sc by calling a method GaussianNB()
GNB = GaussianNB()

# Train the model by calling a method fit()
GNB.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
# Predicting the Test set results
y3_pred = GNB.predict(X_test)
print('The accuracy of the NaiveBayes is',metrics.accuracy_score(y3_pred, y_test))
# Display the predicted values
print(y3_pred)
# Out:
# The accuracy of the NaiveBayes is 1.0
# ['1-9 hours' '1-9 hours' '1-9 hours' '10-19 hours' '10-19 hours'
#  '10-19 hours' '10-19 hours' '20-29 hours' '20-29 hours' '20-29 hours'
#  '30-34 hours' '30-34 hours' '30-34 hours' '30-34 hours' '35-39 hours'
#  '35-39 hours' '35-39 hours' '35-39 hours' '40-44 hours' '40-44 hours'
#  '40-44 hours']

# %%
# Check the actual and predicted value side by side
y_compare = np.vstack((y_test, y3_pred)).T
# actual value on the left side and predicted value on the right hand side
# printing the top 10 values
y_compare[:10, :]
# Out:
# array([['1-9 hours', '1-9 hours'],
#        ['1-9 hours', '1-9 hours'],
#        ['1-9 hours', '1-9 hours'],
#        ['10-19 hours', '10-19 hours'],
#        ['10-19 hours', '10-19 hours'],
#        ['10-19 hours', '10-19 hours'],
#        ['10-19 hours', '10-19 hours'],
#        ['20-29 hours', '20-29 hours'],
#        ['20-29 hours', '20-29 hours'],
#        ['20-29 hours', '20-29 hours']], dtype=object)

# %% [markdown]
# A confusion matrix is a table that is used to describe the performance of a classification model (or "classifier") on a set of test data for which the true values are known. The confusion matrix itself is relatively simple to understand, but the related terminology can be confusing.

# %%
# Construct the Confusion Matrix
cm = confusion_matrix(y_test, y3_pred)
# Call a method heatmap() to plot confusion matrix
sns.heatmap(cm, annot = True)
# print the classification_report based on y_test and y_predict
print(classification_report(y_test, y3_pred))
# Out:
#               precision    recall  f1-score   support
#
#    1-9 hours       1.00      1.00      1.00         3
#  10-19 hours       1.00      1.00      1.00         4
#  20-29 hours       1.00      1.00      1.00         3
#  30-34 hours       1.00      1.00      1.00         4
#  35-39 hours       1.00      1.00      1.00         4
#  40-44 hours       1.00      1.00      1.00         3
#
#     accuracy                           1.00        21
#    macro avg       1.00      1.00      1.00        21
# weighted avg       1.00      1.00      1.00        21

# %%
# Find an accuracy from the confusion matrix
rowsCols = cm.shape
corrPred = 0
falsePred = 0

for row in range(rowsCols[0]):
    for col in range(rowsCols[1]):
        if row == col:
            corrPred += cm[row, col]
        else:
            falsePred += cm[row, col]
print('Correct predictions: ', corrPred)
print('False predictions', falsePred)
print ('\n\nAccuracy of the Naive Bayes Clasification is: ', corrPred/(cm.sum()))
# Out:
# Correct predictions:  21
# False predictions 0
#
#
# Accuracy of the Naive Bayes Clasification is:  1.0

# %%
# Use of Cross Validation
nvclassifier = GaussianNB()
cross_val_score(nvclassifier, X, y, scoring='accuracy').mean()
# Out:
# 0.9454545454545455

# %% [markdown]
# ### 4.4. Support Vector Machine
# Default hyperparameters

# %%
from sklearn.svm import SVC
# Create an object svmModel by calling a method SVC()
svm = SVC() #Default hyperparameters

# Train the model by calling a method fit()
svm.fit(X_train,y_train)
y2_pred=svm.predict(X_test)
print('Accuracy Score:')
print(metrics.accuracy_score(y_test,y2_pred))
# Out:
# Accuracy Score:
# 0.42857142857142855

# %%
# CV on linear kernel¶
svc=SVC(kernel='linear')
scores = cross_val_score(svc, X, y, cv=10, scoring='accuracy') #cv is cross validation
print(scores)
print(scores.mean())
# Out:
# [0.81818182 1.         1.         1.         1.         1.
#  1.         1.         1.         1.        ]
# 0.9818181818181818

# %%
# CV on rbf kernel¶
svc=SVC(kernel='rbf')
scores = cross_val_score(svc, X, y, cv=10, scoring='accuracy') #cv is cross validation
print(scores)
print(scores.mean())
# Out:
# [0.09090909 0.09090909 0.09090909 0.09090909 0.09090909 0.09090909
#  0.09090909 0.09090909 0.2        0.2       ]
# 0.11272727272727272

# %%
svc=SVC(kernel='rbf')
scores = cross_val_score(svc, X, y, cv=10, scoring='accuracy') #cv is cross validation
print(scores)
print(scores.mean())
# Out:
# [0.09090909 0.09090909 0.09090909 0.09090909 0.09090909 0.09090909
#  0.09090909 0.09090909 0.2        0.2       ]
# 0.11272727272727272

# %%
# CV on Polynomial kernel¶
svc=SVC(kernel='linear')
scores = cross_val_score(svc, X, y, cv=10, scoring='accuracy') #cv is cross validation
print(scores)
print(scores.mean())
# Out:
# [0.81818182 1.         1.         1.         1.         1.
#  1.         1.         1.         1.        ]
# 0.9818181818181818

# %%
# Range of different regularization parameter values (C)
C_range=list(np.arange(0.1,6,0.1))
acc_score=[]
for c in C_range:
    svc = SVC(kernel='linear', C=c)
    scores = cross_val_score(svc, X, y, cv=10, scoring='accuracy')
    acc_score.append(scores.mean())
print(acc_score)
# Out:
# [0.9818181818181818, 0.9818181818181818, 0.9818181818181818, 0.9818181818181818, 0.9818181818181818, 0.9818181818181818, 0.9818181818181818, 0.9818181818181818, 0.9818181818181818, 0.9818181818181818, 0.9818181818181818, 0.9818181818181818, 0.9818181818181818, 0.9818181818181818, 0.9818181818181818, 0.9818181818181818, 0.9818181818181818, 0.9818181818181818, 0.9818181818181818, 0.9818181818181818, 0.9818181818181818, 0.9818181818181818, 0.9818181818181818, 0.9818181818181818, 0.9818181818181818, 0.9818181818181818, 0.9818181818181818, 0.9818181818181818, 0.9818181818181818, 0.9818181818181818, 0.9818181818181818, 0.9818181818181818, 0.9818181818181818, 0.9818181818181818, 0.9818181818181818, 0.9818181818181818, 0.9818181818181818, 0.9818181818181818, 0.9818181818181818, 0.9818181818181818, 0.9818181818181818, 0.9818181818181818, 0.9818181818181818, 0.9818181818181818, 0.9818181818181818, 0.9818181818181818, 0.9818181818181818, 0.9818181818181818, 0.9818181818181818, 0.9818181818181818, 0.9818181818181818, 0.9818181818181818, 0.9818181818181818, 0.9818181818181818, 0.9818181818181818, 0.9818181818181818, 0.9818181818181818, 0.9818181818181818, 0.9818181818181818]

# %%
# %matplotlib inline

C_values=list(np.arange(0.1,6,0.1))
# plot the value of C for SVM (x-axis) versus the cross-validated accuracy (y-axis)
plt.plot(C_values,acc_score)
plt.xticks(np.arange(0.0,6,0.3))
plt.xlabel('Value of C for SVC ')
plt.ylabel('Cross-Validated Accuracy')
# Out:
# Text(0, 0.5, 'Cross-Validated Accuracy')

# %% [markdown]
# Taking kernel as linear and taking different values gamma¶

# %%
gamma_range=[0.0001,0.001,0.01,0.1,1,10,100]
acc_score=[]
for g in gamma_range:
    svc = SVC(kernel='linear', gamma=g)
    scores = cross_val_score(svc, X, y, cv=10, scoring='accuracy')
    acc_score.append(scores.mean())
print(acc_score)
# Out:
# [0.9818181818181818, 0.9818181818181818, 0.9818181818181818, 0.9818181818181818, 0.9818181818181818, 0.9818181818181818, 0.9818181818181818]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

gamma_range=[0.0001,0.001,0.01,0.1,1,10,100]

# plot the value of C for SVM (x-axis) versus the cross-validated accuracy (y-axis)
plt.plot(gamma_range,acc_score)
plt.xlabel('Value of gamma for SVC ')
plt.xticks(np.arange(0.0001,100,5))
plt.ylabel('Cross-Validated Accuracy')
# Out:
# Text(0, 0.5, 'Cross-Validated Accuracy')

# %%
degree=[2,3,4,5,6]
acc_score=[]
for d in degree:
    svc = SVC(kernel='linear', degree=d)
    scores = cross_val_score(svc, X, y, cv=10, scoring='accuracy')
    acc_score.append(scores.mean())
print(acc_score)
# Out:
# [0.9818181818181818, 0.9818181818181818, 0.9818181818181818, 0.9818181818181818, 0.9818181818181818]

# %%
degree=[2,3,4,5,6]

# plot the value of C for SVM (x-axis) versus the cross-validated accuracy (y-axis)
plt.plot(degree,acc_score,color='r')
plt.xlabel('degrees for SVC ')
plt.ylabel('Cross-Validated Accuracy')
# Out:
# Text(0, 0.5, 'Cross-Validated Accuracy')

# %%
# Apply model after find the best parameter
svmModel= SVC(kernel="linear")
svmModel.fit(X_train, y_train)
svmModel
# Out:
# SVC(kernel='linear')

# %%
# Predicting the Test set results
y2_pred = svmModel.predict(X_test)
print(metrics.accuracy_score(y2_pred,y_test))
# Out:
# 0.9523809523809523

# %%
# Check the actual and predicted value side by side
y2_compare = np.vstack((y_test, y2_pred)).T
# actual value on the left side and predicted value on the right hand side
# printing the top 10 values
y2_compare[:10, :]
# Out:
# array([['1-9 hours', '1-9 hours'],
#        ['1-9 hours', '1-9 hours'],
#        ['1-9 hours', '1-9 hours'],
#        ['10-19 hours', '10-19 hours'],
#        ['10-19 hours', '10-19 hours'],
#        ['10-19 hours', '10-19 hours'],
#        ['10-19 hours', '10-19 hours'],
#        ['20-29 hours', '30-34 hours'],
#        ['20-29 hours', '20-29 hours'],
#        ['20-29 hours', '20-29 hours']], dtype=object)

# %%
# Use of Cross Validation
cross_val_score(svmModel, X, y, cv=10, scoring='accuracy').mean()
# Out:
# 0.9818181818181818

# %% [markdown]
# ### 4.5. Logistic Regression

# %% [markdown]
# Feature ranking with recursive Feature elimination and Cross-Validation.

# %%
from sklearn.feature_selection import RFECV
# Create the RFE object and compute a cross-validated score.
# The "accuracy" scoring is proportional to the number of correct classifications
rfecv = RFECV(estimator=LogisticRegression(), step=1, cv=10, scoring='accuracy')
rfecv.fit(X, y)

print("Optimal number of features: %d" % rfecv.n_features_)
print('Selected features: %s' % list(X.columns[rfecv.support_]))

# Plot number of features and cross-validation scores
plt.figure()
plt.xlabel("Number of features selected")
plt.ylabel("Cross-validation score (mean accuracy)")
plt.plot(range(1, len(rfecv.cv_results_['mean_test_score']) + 1), rfecv.cv_results_['mean_test_score'])
plt.show()
# Out:
# Optimal number of features: 7
# Selected features: ['VALUE(hours)', 'VALUE(nationality)', 'Nationality', 'VALUE(sector)', 'NACE Rev 2 Economic Sector', 'VALUE(education)', 'Education Level']

# %%
# Selecting features
Selected_features= ['VALUE(hours)', 'VALUE(nationality)', 'Nationality', 'VALUE(sector)',
                     'NACE Rev 2 Economic Sector', 'VALUE(education)', 'Education Level'
                   ]
                   
X = X[Selected_features]

# Plot the correlation heatmap
plt.subplots(figsize=(8, 5))
sns.heatmap(X.corr(), annot=True, cmap="RdYlGn")
plt.show()

# %% [markdown]
# Interpreting The Heatmap
# The first thing to note is that only the numeric features are compared as it is obvious that we cannot correlate between alphabets or strings.
#
# POSITIVE CORRELATION: If an increase in feature A leads to increase in feature B, then they are positively correlated. A value 1 means perfect positive correlation.
#
# NEGATIVE CORRELATION: If an increase in feature A leads to decrease in feature B, then they are negatively correlated. A value -1 means perfect negative correlation.

# %%
# Split with selected features
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=2)
# Number of rows and columns before (X, y) and after Splitting (X_train, X_test, y_train, y_test)
X.shape, y.shape, X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((108, 7), (108,), (81, 7), (27, 7), (81,), (27,))

# %% [markdown]
# By the experiment conducted by (Andreas and Sarah, 2017), logistic regression models were trained different C hyperparameter values, and obtained the corresponding accuracy values for each C.

# %%
from sklearn.linear_model import LogisticRegression
# Create a Logistic Regression model for multi-class classification
LR = LogisticRegression(C=1.0, multi_class='ovr',solver='liblinear', random_state=0)

# Fit the model to the training data
LR.fit(X_train, y_train)
# Out:
# LogisticRegression(multi_class='ovr', random_state=0, solver='liblinear')

# %% [markdown]
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#            random_state=0, solver='liblinear', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
from sklearn.metrics import roc_curve, log_loss
# Predict on the test data
y_pred4 = LR.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred4)
report = classification_report(y_test, y_pred4)

print(f'Accuracy: {accuracy}')
print(f'Classification Report:\n{report}')
# Construct the Confusion Matrix
cm = confusion_matrix(y_test, y_pred4)
# Call a method heatmap() to plot confusion matrix
sns.heatmap(cm, annot = True)
# Out:
# Accuracy: 0.9629629629629629
# Classification Report:
#               precision    recall  f1-score   support
#
#    1-9 hours       1.00      1.00      1.00         7
#  10-19 hours       0.88      1.00      0.93         7
#  20-29 hours       1.00      0.67      0.80         3
#  30-34 hours       1.00      1.00      1.00         4
#  35-39 hours       1.00      1.00      1.00         1
#  40-44 hours       1.00      1.00      1.00         5
#
#     accuracy                           0.96        27
#    macro avg       0.98      0.94      0.96        27
# weighted avg       0.97      0.96      0.96        27
# <Axes: >

# %% [markdown]
# ### 4.6. Artificial neural networks

# %%
# Replacing index string to integer 
replacement_dict = {
    '1-9 hours': 0,
    '10-19 hours': 0,
    '20-29 hours': 1,
    '30-34 hours': 1,
    '35-39 hours': 1,
    '40-44 hours': 1,
    '45 hours and over': 1
}

df_h['Usual Hours Worked'] = df_h['Usual Hours Worked'].replace(replacement_dict)

# %%
y1=df_h["Usual Hours Worked"].values
y1 = y1[:-14]

# %%
# Split the data set into Training and Testing parts
X_train, X_test, y_train, y_test = train_test_split(X, y1, test_size = 0.25, random_state = 20)

# %%
from keras.models import Sequential
from keras.layers import Dense
#define the keras model
ANN= Sequential()
ANN.add(Dense(16, input_dim=7, activation='relu'))
ANN.add(Dense(8, activation='relu'))
ANN.add(Dense(1, activation='sigmoid'))
ANN.summary()
# Out:
# Metal device set to: Apple M1
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 16)                128
#
#  dense_1 (Dense)             (None, 8)                 136
#
#  dense_2 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 273
# Trainable params: 273
# Non-trainable params: 0
# _________________________________________________________________
# 2023-09-22 00:01:03.272906: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-09-22 00:01:03.273273: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
# compile the keras model
ANN.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# Instantiate the scaler
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)

# %%
# fit the keras model on the dataset
ANN.fit(X_train, y_train, epochs=100, batch_size=32)
# Out:
# Epoch 1/100
# 2023-09-22 00:01:03.448960: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2023-09-22 00:01:03.653444: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 3/3 [==============================] - 0s 42ms/step - loss: 12.5462 - accuracy: 0.6543
# Epoch 2/100
# 3/3 [==============================] - 0s 8ms/step - loss: 10.6097 - accuracy: 0.6543
# Epoch 3/100
# 3/3 [==============================] - 0s 9ms/step - loss: 8.7146 - accuracy: 0.6543
# Epoch 4/100
# 3/3 [==============================] - 0s 8ms/step - loss: 7.0030 - accuracy: 0.6543
# Epoch 5/100
# 3/3 [==============================] - 0s 8ms/step - loss: 5.2879 - accuracy: 0.5926
# Epoch 6/100
# 3/3 [==============================] - 0s 8ms/step - loss: 3.8776 - accuracy: 0.6049
# Epoch 7/100
# 3/3 [==============================] - 0s 8ms/step - loss: 2.6222 - accuracy: 0.5679
# Epoch 8/100
# 3/3 [==============================] - 0s 8ms/step - loss: 1.6596 - accuracy: 0.6049
# Epoch 9/100
# 3/3 [==============================] - 0s 8ms/step - loss: 1.0006 - accuracy: 0.7407
# Epoch 10/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.6400 - accuracy: 0.8025
# Epoch 11/100
# 3/3 [==============================] - 0s 9ms/step - loss: 0.3399 - accuracy: 0.8519
# Epoch 12/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.1868 - accuracy: 0.9012
# Epoch 13/100
# 3/3 [==============================] - 0s 9ms/step - loss: 0.1316 - accuracy: 0.9506
# Epoch 14/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.1059 - accuracy: 0.9753
# Epoch 15/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0876 - accuracy: 0.9877
# Epoch 16/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0753 - accuracy: 0.9877
# Epoch 17/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0648 - accuracy: 0.9877
# Epoch 18/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0561 - accuracy: 0.9877
# Epoch 19/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0501 - accuracy: 0.9877
# Epoch 20/100
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0463 - accuracy: 0.9877
# Epoch 21/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0438 - accuracy: 0.9877
# Epoch 22/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0416 - accuracy: 0.9877
# Epoch 23/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0405 - accuracy: 0.9877
# Epoch 24/100
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0397 - accuracy: 0.9877
# Epoch 25/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0385 - accuracy: 0.9877
# Epoch 26/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0370 - accuracy: 0.9877
# Epoch 27/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0359 - accuracy: 0.9877
# Epoch 28/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0344 - accuracy: 0.9877
# Epoch 29/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0334 - accuracy: 0.9877
# Epoch 30/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0327 - accuracy: 0.9877
# Epoch 31/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0317 - accuracy: 0.9877
# Epoch 32/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0308 - accuracy: 0.9877
# Epoch 33/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0300 - accuracy: 0.9877
# Epoch 34/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0294 - accuracy: 0.9877
# Epoch 35/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0283 - accuracy: 0.9877
# Epoch 36/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0276 - accuracy: 0.9877
# Epoch 37/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0270 - accuracy: 0.9877
# Epoch 38/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0265 - accuracy: 0.9877
# Epoch 39/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0258 - accuracy: 0.9877
# Epoch 40/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0253 - accuracy: 0.9877
# Epoch 41/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0248 - accuracy: 1.0000
# Epoch 42/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0242 - accuracy: 1.0000
# Epoch 43/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0237 - accuracy: 1.0000
# Epoch 44/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0232 - accuracy: 1.0000
# Epoch 45/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0228 - accuracy: 1.0000
# Epoch 46/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0223 - accuracy: 1.0000
# Epoch 47/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0219 - accuracy: 1.0000
# Epoch 48/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0214 - accuracy: 1.0000
# Epoch 49/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0209 - accuracy: 1.0000
# Epoch 50/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0205 - accuracy: 1.0000
# Epoch 51/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0199 - accuracy: 1.0000
# Epoch 52/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0195 - accuracy: 1.0000
# Epoch 53/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0190 - accuracy: 1.0000
# Epoch 54/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0187 - accuracy: 1.0000
# Epoch 55/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0182 - accuracy: 1.0000
# Epoch 56/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0178 - accuracy: 1.0000
# Epoch 57/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0174 - accuracy: 1.0000
# Epoch 58/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0170 - accuracy: 1.0000
# Epoch 59/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0166 - accuracy: 1.0000
# Epoch 60/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0163 - accuracy: 1.0000
# Epoch 61/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0159 - accuracy: 1.0000
# Epoch 62/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0156 - accuracy: 1.0000
# Epoch 63/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0152 - accuracy: 1.0000
# Epoch 64/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0149 - accuracy: 1.0000
# Epoch 65/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0146 - accuracy: 1.0000
# Epoch 66/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0144 - accuracy: 1.0000
# Epoch 67/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0141 - accuracy: 1.0000
# Epoch 68/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0138 - accuracy: 1.0000
# Epoch 69/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0136 - accuracy: 1.0000
# Epoch 70/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0133 - accuracy: 1.0000
# Epoch 71/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0131 - accuracy: 1.0000
# Epoch 72/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0128 - accuracy: 1.0000
# Epoch 73/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0126 - accuracy: 1.0000
# Epoch 74/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0123 - accuracy: 1.0000
# Epoch 75/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0122 - accuracy: 1.0000
# Epoch 76/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0119 - accuracy: 1.0000
# Epoch 77/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0117 - accuracy: 1.0000
# Epoch 78/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0114 - accuracy: 1.0000
# Epoch 79/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0112 - accuracy: 1.0000
# Epoch 80/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0111 - accuracy: 1.0000
# Epoch 81/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0109 - accuracy: 1.0000
# Epoch 82/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0107 - accuracy: 1.0000
# Epoch 83/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0105 - accuracy: 1.0000
# Epoch 84/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0103 - accuracy: 1.0000
# Epoch 85/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0102 - accuracy: 1.0000
# Epoch 86/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0100 - accuracy: 1.0000
# Epoch 87/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0099 - accuracy: 1.0000
# Epoch 88/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0097 - accuracy: 1.0000
# Epoch 89/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0095 - accuracy: 1.0000
# Epoch 90/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0094 - accuracy: 1.0000
# Epoch 91/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0093 - accuracy: 1.0000
# Epoch 92/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0091 - accuracy: 1.0000
# Epoch 93/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0090 - accuracy: 1.0000
# Epoch 94/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0089 - accuracy: 1.0000
# Epoch 95/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0088 - accuracy: 1.0000
# Epoch 96/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0086 - accuracy: 1.0000
# Epoch 97/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0085 - accuracy: 1.0000
# Epoch 98/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0084 - accuracy: 1.0000
# Epoch 99/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0083 - accuracy: 1.0000
# Epoch 100/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0082 - accuracy: 1.0000

# %%
history = ANN.fit(X_test, y_test, validation_split=0.20, epochs=100, batch_size=32, verbose=1)
# Plot training & validation accuracy values
# Out:
# Epoch 1/100
# 1/1 [==============================] - 0s 209ms/step - loss: 0.2667 - accuracy: 0.9524 - val_loss: 1.0228 - val_accuracy: 0.6667
# Epoch 2/100
# 1/1 [==============================] - 0s 24ms/step - loss: 0.2600 - accuracy: 0.9524 - val_loss: 0.9922 - val_accuracy: 0.6667
# Epoch 3/100
# 1/1 [==============================] - 0s 27ms/step - loss: 0.2477 - accuracy: 0.9524 - val_loss: 0.9493 - val_accuracy: 0.6667
# Epoch 4/100
# 1/1 [==============================] - 0s 26ms/step - loss: 0.2304 - accuracy: 0.9524 - val_loss: 0.8967 - val_accuracy: 0.6667
# Epoch 5/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.2089 - accuracy: 0.9524 - val_loss: 0.8383 - val_accuracy: 0.6667
# Epoch 6/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1841 - accuracy: 0.9524
# 2023-09-22 00:01:06.541135: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 1/1 [==============================] - 0s 28ms/step - loss: 0.1841 - accuracy: 0.9524 - val_loss: 0.7796 - val_accuracy: 0.6667
# Epoch 7/100
# 1/1 [==============================] - 0s 27ms/step - loss: 0.1569 - accuracy: 0.9524 - val_loss: 0.7290 - val_accuracy: 0.6667
# Epoch 8/100
# 1/1 [==============================] - 0s 22ms/step - loss: 0.1285 - accuracy: 0.9524 - val_loss: 0.6956 - val_accuracy: 0.8333
# Epoch 9/100
# 1/1 [==============================] - 0s 25ms/step - loss: 0.1009 - accuracy: 0.9524 - val_loss: 0.6841 - val_accuracy: 0.8333
# Epoch 10/100
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0766 - accuracy: 0.9524 - val_loss: 0.6905 - val_accuracy: 0.8333
# Epoch 11/100
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0585 - accuracy: 1.0000 - val_loss: 0.7056 - val_accuracy: 0.8333
# Epoch 12/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0473 - accuracy: 1.0000 - val_loss: 0.7217 - val_accuracy: 0.8333
# Epoch 13/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0412 - accuracy: 1.0000 - val_loss: 0.7343 - val_accuracy: 0.8333
# Epoch 14/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0378 - accuracy: 1.0000 - val_loss: 0.7412 - val_accuracy: 0.8333
# Epoch 15/100
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0356 - accuracy: 1.0000 - val_loss: 0.7419 - val_accuracy: 0.8333
# Epoch 16/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0337 - accuracy: 1.0000 - val_loss: 0.7365 - val_accuracy: 0.8333
# Epoch 17/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0316 - accuracy: 1.0000 - val_loss: 0.7257 - val_accuracy: 0.8333
# Epoch 18/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0294 - accuracy: 1.0000 - val_loss: 0.7102 - val_accuracy: 0.8333
# Epoch 19/100
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0270 - accuracy: 1.0000 - val_loss: 0.6909 - val_accuracy: 0.8333
# Epoch 20/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0246 - accuracy: 1.0000 - val_loss: 0.6687 - val_accuracy: 0.8333
# Epoch 21/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0223 - accuracy: 1.0000 - val_loss: 0.6444 - val_accuracy: 0.8333
# Epoch 22/100
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0201 - accuracy: 1.0000 - val_loss: 0.6188 - val_accuracy: 0.8333
# Epoch 23/100
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0182 - accuracy: 1.0000 - val_loss: 0.5925 - val_accuracy: 0.8333
# Epoch 24/100
# 1/1 [==============================] - 0s 25ms/step - loss: 0.0165 - accuracy: 1.0000 - val_loss: 0.5663 - val_accuracy: 0.8333
# Epoch 25/100
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0150 - accuracy: 1.0000 - val_loss: 0.5404 - val_accuracy: 0.8333
# Epoch 26/100
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0138 - accuracy: 1.0000 - val_loss: 0.5153 - val_accuracy: 0.8333
# Epoch 27/100
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0128 - accuracy: 1.0000 - val_loss: 0.4913 - val_accuracy: 0.8333
# Epoch 28/100
# 1/1 [==============================] - 0s 25ms/step - loss: 0.0120 - accuracy: 1.0000 - val_loss: 0.4685 - val_accuracy: 0.8333
# Epoch 29/100
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0114 - accuracy: 1.0000 - val_loss: 0.4472 - val_accuracy: 0.8333
# Epoch 30/100
# 1/1 [==============================] - 0s 26ms/step - loss: 0.0109 - accuracy: 1.0000 - val_loss: 0.4273 - val_accuracy: 0.8333
# Epoch 31/100
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0105 - accuracy: 1.0000 - val_loss: 0.4070 - val_accuracy: 0.8333
# Epoch 32/100
# 1/1 [==============================] - 0s 26ms/step - loss: 0.0102 - accuracy: 1.0000 - val_loss: 0.3866 - val_accuracy: 0.8333
# Epoch 33/100
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0100 - accuracy: 1.0000 - val_loss: 0.3681 - val_accuracy: 0.8333
# Epoch 34/100
# 1/1 [==============================] - 0s 25ms/step - loss: 0.0098 - accuracy: 1.0000 - val_loss: 0.3507 - val_accuracy: 0.8333
# Epoch 35/100
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0097 - accuracy: 1.0000 - val_loss: 0.3346 - val_accuracy: 0.8333
# Epoch 36/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0097 - accuracy: 1.0000 - val_loss: 0.3198 - val_accuracy: 0.8333
# Epoch 37/100
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0096 - accuracy: 1.0000 - val_loss: 0.3064 - val_accuracy: 0.8333
# Epoch 38/100
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0096 - accuracy: 1.0000 - val_loss: 0.2942 - val_accuracy: 0.8333
# Epoch 39/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0096 - accuracy: 1.0000 - val_loss: 0.2834 - val_accuracy: 0.8333
# Epoch 40/100
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0096 - accuracy: 1.0000 - val_loss: 0.2738 - val_accuracy: 0.8333
# Epoch 41/100
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0096 - accuracy: 1.0000 - val_loss: 0.2653 - val_accuracy: 0.8333
# Epoch 42/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0096 - accuracy: 1.0000 - val_loss: 0.2580 - val_accuracy: 0.8333
# Epoch 43/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0095 - accuracy: 1.0000 - val_loss: 0.2517 - val_accuracy: 0.8333
# Epoch 44/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0095 - accuracy: 1.0000 - val_loss: 0.2464 - val_accuracy: 0.8333
# Epoch 45/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0095 - accuracy: 1.0000 - val_loss: 0.2419 - val_accuracy: 0.8333
# Epoch 46/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0094 - accuracy: 1.0000 - val_loss: 0.2382 - val_accuracy: 0.8333
# Epoch 47/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0094 - accuracy: 1.0000 - val_loss: 0.2352 - val_accuracy: 0.8333
# Epoch 48/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0093 - accuracy: 1.0000 - val_loss: 0.2328 - val_accuracy: 0.8333
# Epoch 49/100
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0092 - accuracy: 1.0000 - val_loss: 0.2310 - val_accuracy: 0.8333
# Epoch 50/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0091 - accuracy: 1.0000 - val_loss: 0.2297 - val_accuracy: 0.8333
# Epoch 51/100
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0090 - accuracy: 1.0000 - val_loss: 0.2288 - val_accuracy: 0.8333
# Epoch 52/100
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0089 - accuracy: 1.0000 - val_loss: 0.2283 - val_accuracy: 0.8333
# Epoch 53/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0088 - accuracy: 1.0000 - val_loss: 0.2281 - val_accuracy: 0.8333
# Epoch 54/100
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0088 - accuracy: 1.0000 - val_loss: 0.2281 - val_accuracy: 0.8333
# Epoch 55/100
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0087 - accuracy: 1.0000 - val_loss: 0.2284 - val_accuracy: 0.8333
# Epoch 56/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0086 - accuracy: 1.0000 - val_loss: 0.2288 - val_accuracy: 0.8333
# Epoch 57/100
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0085 - accuracy: 1.0000 - val_loss: 0.2293 - val_accuracy: 0.8333
# Epoch 58/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0084 - accuracy: 1.0000 - val_loss: 0.2299 - val_accuracy: 0.8333
# Epoch 59/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0083 - accuracy: 1.0000 - val_loss: 0.2305 - val_accuracy: 0.8333
# Epoch 60/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0082 - accuracy: 1.0000 - val_loss: 0.2312 - val_accuracy: 0.8333
# Epoch 61/100
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0081 - accuracy: 1.0000 - val_loss: 0.2318 - val_accuracy: 0.8333
# Epoch 62/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0081 - accuracy: 1.0000 - val_loss: 0.2324 - val_accuracy: 0.8333
# Epoch 63/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0080 - accuracy: 1.0000 - val_loss: 0.2329 - val_accuracy: 0.8333
# Epoch 64/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0079 - accuracy: 1.0000 - val_loss: 0.2333 - val_accuracy: 0.8333
# Epoch 65/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0078 - accuracy: 1.0000 - val_loss: 0.2337 - val_accuracy: 0.8333
# Epoch 66/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0078 - accuracy: 1.0000 - val_loss: 0.2339 - val_accuracy: 0.8333
# Epoch 67/100
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0077 - accuracy: 1.0000 - val_loss: 0.2340 - val_accuracy: 0.8333
# Epoch 68/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0077 - accuracy: 1.0000 - val_loss: 0.2340 - val_accuracy: 0.8333
# Epoch 69/100
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0076 - accuracy: 1.0000 - val_loss: 0.2338 - val_accuracy: 0.8333
# Epoch 70/100
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0075 - accuracy: 1.0000 - val_loss: 0.2335 - val_accuracy: 0.8333
# Epoch 71/100
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0075 - accuracy: 1.0000 - val_loss: 0.2331 - val_accuracy: 0.8333
# Epoch 72/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0074 - accuracy: 1.0000 - val_loss: 0.2325 - val_accuracy: 0.8333
# Epoch 73/100
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0074 - accuracy: 1.0000 - val_loss: 0.2318 - val_accuracy: 0.8333
# Epoch 74/100
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0073 - accuracy: 1.0000 - val_loss: 0.2309 - val_accuracy: 0.8333
# Epoch 75/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0073 - accuracy: 1.0000 - val_loss: 0.2299 - val_accuracy: 0.8333
# Epoch 76/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0073 - accuracy: 1.0000 - val_loss: 0.2288 - val_accuracy: 0.8333
# Epoch 77/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0072 - accuracy: 1.0000 - val_loss: 0.2276 - val_accuracy: 0.8333
# Epoch 78/100
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0072 - accuracy: 1.0000 - val_loss: 0.2263 - val_accuracy: 0.8333
# Epoch 79/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0071 - accuracy: 1.0000 - val_loss: 0.2249 - val_accuracy: 0.8333
# Epoch 80/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0071 - accuracy: 1.0000 - val_loss: 0.2234 - val_accuracy: 0.8333
# Epoch 81/100
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0070 - accuracy: 1.0000 - val_loss: 0.2218 - val_accuracy: 0.8333
# Epoch 82/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0070 - accuracy: 1.0000 - val_loss: 0.2202 - val_accuracy: 0.8333
# Epoch 83/100
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0070 - accuracy: 1.0000 - val_loss: 0.2184 - val_accuracy: 0.8333
# Epoch 84/100
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0069 - accuracy: 1.0000 - val_loss: 0.2166 - val_accuracy: 0.8333
# Epoch 85/100
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0069 - accuracy: 1.0000 - val_loss: 0.2148 - val_accuracy: 0.8333
# Epoch 86/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0068 - accuracy: 1.0000 - val_loss: 0.2129 - val_accuracy: 0.8333
# Epoch 87/100
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0068 - accuracy: 1.0000 - val_loss: 0.2110 - val_accuracy: 0.8333
# Epoch 88/100
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0068 - accuracy: 1.0000 - val_loss: 0.2091 - val_accuracy: 0.8333
# Epoch 89/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.2071 - val_accuracy: 0.8333
# Epoch 90/100
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.2052 - val_accuracy: 0.8333
# Epoch 91/100
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.2032 - val_accuracy: 0.8333
# Epoch 92/100
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0066 - accuracy: 1.0000 - val_loss: 0.2012 - val_accuracy: 0.8333
# Epoch 93/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0066 - accuracy: 1.0000 - val_loss: 0.1992 - val_accuracy: 0.8333
# Epoch 94/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0066 - accuracy: 1.0000 - val_loss: 0.1972 - val_accuracy: 0.8333
# Epoch 95/100
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0065 - accuracy: 1.0000 - val_loss: 0.1953 - val_accuracy: 0.8333
# Epoch 96/100
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0065 - accuracy: 1.0000 - val_loss: 0.1933 - val_accuracy: 0.8333
# Epoch 97/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.1914 - val_accuracy: 0.8333
# Epoch 98/100
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.1895 - val_accuracy: 0.8333
# Epoch 99/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.1876 - val_accuracy: 0.8333
# Epoch 100/100
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.1858 - val_accuracy: 0.8333

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
# Save the model
ANN.save("Working_hour.h5")

# %%
# evaluate the keras model
_, accuracy=ANN.evaluate(X_train,y_train)
print('Training Accuracy: %.2f' % (accuracy*100))
_, accuracy=ANN.evaluate(X_test,y_test)
print('Testing Accuracy: %.2f' % (accuracy*100))
# Out:
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0101 - accuracy: 1.0000
# Training Accuracy: 100.00
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0462 - accuracy: 0.9630
# Testing Accuracy: 96.30

# %%
# make probability predictions with the model
predictions= ANN.predict(X_test)
# Out:
# 1/1 [==============================] - 0s 46ms/step
# 2023-09-22 00:01:09.451825: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.

# %%
predictions.shape
y1=y1[:27]
y1.shape
# Out:
# (27,)

# %%
import matplotlib.pyplot as plt
plt.plot(y_test, label="Measured")
plt.plot(predictions, label='Predicted')
plt.legend()
plt.ylabel("Hours")
plt.title("Measured and Predicted values")
plt.show()

# %% [markdown]
# ### Model evaluation

# %%
algorithms = ["SVC", "GaussianNB", "LR", "RFC", "DTC", "ANN"]
cross_validation = [0.42, 0.94, 0.90, 0.90, 0.92, 0.96]
accuracy = [0.95, 1.0, 0.96, 0.89, 0.81, 0.96]

# Create a figure and axis
fig, ax = plt.subplots(figsize=(10, 6))

# Set the width of the bars
bar_width = 0.35

# Create a bar for cross-validation scores
index = np.arange(len(algorithms))
bar1 = ax.bar(index, cross_validation, bar_width, label='Cross-Validation', alpha=0.7, color='b')

# Create a bar for accuracy scores
bar2 = ax.bar(index + bar_width, accuracy, bar_width, label='Accuracy', alpha=0.7, color='g')

# Customize the plot
ax.set_xlabel('Algorithms')
ax.set_ylabel('Scores')
ax.set_title('Cross-Validation and Accuracy Scores by Algorithms')
ax.set_xticks(index + bar_width / 2)
ax.set_xticklabels(algorithms)
ax.legend()

# Add values on top of the bars
for rect in bar1 + bar2:
    height = rect.get_height()
    ax.annotate(f'{height:.2f}', xy=(rect.get_x() + rect.get_width() / 2, height),
                xytext=(0, 3),  # 3 points vertical offset
                textcoords="offset points",
                ha='center', va='bottom')

plt.show()

# %% [markdown]
# ### Feature Importance¶
# Feature importance rankings among different tree-based models. Each subplot shows the features sorted by their importance for the respective model.

# %%
# Define the models and their names
models = [
    RandomForestClassifier(n_estimators=100, random_state=0),
    DecisionTreeClassifier(max_depth=4),
]

model_names = ['Random Forest', 'Decision Tree']

# Create a 1x2 grid of subplots
fig, axes = plt.subplots(1, 2, figsize=(15, 12))
axes = axes.flatten()

# Define colors for bars
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728']

# Loop through models and axes to plot feature importances
for model, model_name, ax, color in zip(models, model_names, axes, colors):
    model.fit(X, y)
    feature_importance = pd.Series(model.feature_importances_, X.columns).sort_values(ascending=True)
    feature_importance.plot(kind='barh', width=0.8, ax=ax, color=color)
    ax.set_title(f'Feature Importance in {model_name}')

    # Display feature importance values on the bars
    for i, v in enumerate(feature_importance):
        ax.text(v + 0.01, i, f'{v:.2f}', color='black', va='center')
# Adjust subplot layout
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Permutation importance

# %% [markdown]
# Permutation importance for each feature in your models alongside the original feature importance. Permutation importance provides a different perspective on feature importance by measuring the change in model performance when the values of each feature are randomly shuffled.

# %%
from sklearn.inspection import permutation_importance

# Define the models and their names
models = [
    RandomForestClassifier(n_estimators=100, random_state=0),
    DecisionTreeClassifier(max_depth=4),
]

model_names = ['Random Forest', 'Decision Tree']

# Create a 2x1 grid of subplots
fig, axes = plt.subplots(1, 2, figsize=(15, 6))
axes = axes.flatten()

# Define colors for bars
colors = ['#1f77b4', '#ff7f0e']

# Loop through models and axes to plot feature importances
for model, model_name, ax, color in zip(models, model_names, axes, colors):
    model.fit(X, y)
    
    # Calculate permutation importance for the current model
    perm_importance = permutation_importance(model, X, y, n_repeats=30, random_state=0)
    feature_importance = perm_importance.importances_mean
    
    # Sort feature importances
    sorted_idx = feature_importance.argsort()
    feature_importance_sorted = feature_importance[sorted_idx]
    feature_names_sorted = X.columns[sorted_idx]
    
    # Plot permutation importance
    ax.barh(feature_names_sorted, feature_importance_sorted, color=color)
    ax.set_title(f'Permutation Importance in {model_name}')
    
    # Add permutation importance values as text labels on the bars
    for i, v in enumerate(feature_importance_sorted):
        ax.text(v, i, f'{v:.2f}', color='black', va='center')
   
# Adjust subplot layout
plt.tight_layout()
plt.show()
